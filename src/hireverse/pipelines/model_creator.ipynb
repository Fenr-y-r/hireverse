# %% [markdown]
# # Input

# %%
target_column = "RecommendHiring"
# %load_ext autoreload
# %autoreload 2
VIDEOS_FOLDER = "./data/raw/videos"
import importlib.util
from pathlib import Path
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Constants

# %%
import os
import numpy as np
from sklearn.metrics import make_scorer

SCRIPT_DIR = os.path.join(os.getcwd(),)

SAVED_MODELS_PATH="./../../model_artifacts"

DROPPED_LEXICAL_COLUMNS = [
    "Swear",
    "Numbers",
    "Inhibition",
    "Preceptual",
    "Anxiety",
    "Anger",
    "Sadness",
    "Work",
    "Articles",
    "Verbs",
    "Adverbs",
    "Prepositions",
    "Conjunctions",
    "Negations",
]

facial_features = [
    "average_inner_brow_height",
    "average_outer_brow_height",
    "eye_open",
    "inner_lip_height",
    "lip_corner_distance",
    "outer_lip_height",
    "smile",
    "pitch",
    "roll",
    "yaw",
]

stats = ["max", "median", "min", "std"]
DROPPED_FACIAL_FEATURES = [
    f"{feature}_{stat}" for feature in facial_features for stat in stats
]


DROPPED_PROSODIC_COLUMNS = []

ALREADY_NORMALIZED_FEATURES = [
    "average_outer_brow_height_mean",
    "average_inner_brow_height_mean",
    "eye_open_mean",
    "inner_lip_height_mean",
    "inner_lip_height_mean",
    "lip_corner_distance_mean",
    "average_outer_brow_height_std",
    "average_inner_brow_height_std",
    "eye_open_std",
    "outer_lip_height_std",
    "inner_lip_height_std",
    "lip_corner_distance_std",
    "average_outer_brow_height_min",
    "average_inner_brow_height_min",
    "eye_open_min",
    "outer_lip_height_min",
    "inner_lip_height_min",
    "lip_corner_distance_min",
    "average_outer_brow_height_max",
    "average_inner_brow_height_max",
    "eye_open_max",
    "outer_lip_height_max",
    "inner_lip_height_max",
    "lip_corner_distance_max",
    "average_outer_brow_height_median",
    "average_inner_brow_height_median",
    "eye_open_median",
    "outer_lip_height_median",
    "inner_lip_height_median",
    "lip_corner_distance_median",
]  # these are already in [0, 1]

MUST_KEEP_FEATURES = [
    "pause_duration_avg",
    "average_outer_brow_height_mean",
    "average_inner_brow_height_mean",
    "outer_lip_height_mean",
    "Duration/Filler Words",
]


GROUPS_COLUMN = "cleaned_ids"
INDEX_COLUMN = "participant_id"


def pearson_corr(y_true, y_pred):
    return np.corrcoef(y_true, y_pred)[0, 1]


SCORING_METRICS = {
    "r2": "r2",
    "mae": "neg_mean_absolute_error",
    "pearson": make_scorer(pearson_corr),  # Pearson Correlation Coefficient
}


MUST_KEEP_FEATURES = [
    # "pause_duration_avg",
    # "average_outer_brow_height_mean",
    # "average_inner_brow_height_mean",
    # "outer_lip_height_mean",
    "Duration/Filler Words",
]

PIPELINE_PARAMS = {'feature_selection__estimator__alpha': 0.057376790661083456, 'svr__C': 0.655379988356498, 'svr__gamma': 0.02784736494309893, 'svr__epsilon': 0.2617249201838037, 'svr__kernel': 'rbf'}
HYPERPARAMETER_TUNING_ENABLED = True

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Import Datasets

# %%
import pandas as pd
import os
from hireverse.utils.utils import * 
features_df = pd.read_csv(BASE_DIR+"/data/external/add.csv")
features_df = features_df.set_index("participant_id")

labels_df = pd.read_csv(
    os.path.join(BASE_DIR+"/data/external/turker_scores_full_interview.csv")
)
labels_df = labels_df.set_index("Participant")
labels_df = labels_df.loc[labels_df["Worker"] == "AGGR"]

features_df.index = features_df.index.str.lower()
labels_df.index = labels_df.index.str.lower()
indexed_combined_df = features_df.join(labels_df[[target_column]], how="left")
combined_df = indexed_combined_df.reset_index(drop=True)

# %% [markdown]
# # Model

# %% [markdown]
# ## Split Data

# %%
X = combined_df.drop(columns=[target_column, GROUPS_COLUMN])
y = combined_df[target_column]

# %% [markdown]
# ## Pipeline Creation

# %%
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import SelectFromModel
from sklearn.impute import SimpleImputer
from sklearn.linear_model import Lasso
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.model_selection import GroupKFold, cross_val_score, cross_validate
import sys

groups_column = combined_df[GROUPS_COLUMN].astype(str).values

preprocessor = ColumnTransformer(
    [
        ('dropper', 'drop', DROPPED_FACIAL_FEATURES + 
                            DROPPED_LEXICAL_COLUMNS + 
                            DROPPED_PROSODIC_COLUMNS)
    ],
    remainder='passthrough'
)
unfitted_pipeline = Pipeline(
    [
        ('preprocessor', preprocessor),
        ("imputer", SimpleImputer(strategy="mean")),  # NaN imputation
        ("scaler", StandardScaler()),
        ("feature_selection", SelectFromModel(estimator=Lasso(max_iter=50000), )),
        # ('feature_selection', DomainAwareSelector(
        #     must_keep_features=MUST_KEEP_FEATURES,
        #     selector=SelectFromModel(lasso_feature_selection_model, max_features=10),
        # )),
        ("svr", SVR(kernel="rbf")),
    ]
)

# %% [markdown]
# ## Hyperparameter Tuning

# %%
import optuna
from sklearn.base import clone
from sklearn.model_selection import GroupShuffleSplit, cross_val_score
import numpy as np

def objective(trial):
    pipeline_clone = clone(unfitted_pipeline)  # Clone pipeline for thread safety
    
    params = {
        "feature_selection__estimator__alpha": trial.suggest_float(
        "feature_selection__estimator__alpha", 1e-4, 0.1, log=True  # Adjusted lower bound
        ),
        "svr__C": trial.suggest_float("svr__C", 0.01, 100, log=True),
        "svr__gamma": trial.suggest_float("svr__gamma", 1e-3, 1e1, log=True),
        "svr__epsilon": trial.suggest_float("svr__epsilon", 0.01, 0.5),
        "svr__kernel": trial.suggest_categorical("svr__kernel", ["rbf"
                                                                #  , "poly"
                                                                 ]),
    }
    
    # if params["svr__kernel"] == "poly":
    #     params["svr__degree"] = trial.suggest_int("svr__degree", 2, 3)  # Reduced from 5
    #     params["svr__coef0"] = trial.suggest_float("svr__coef0", 0.0, 0.5)  # Narrower range
        
    pipeline_clone.set_params(**params)
    
    mc_cv_tuning = GroupShuffleSplit(n_splits=20, test_size=0.2, random_state=42)
    
    scores = cross_val_score(
        pipeline_clone, X, y, cv=mc_cv_tuning, groups=groups_column, n_jobs=1
    )

    return np.mean(scores)

if HYPERPARAMETER_TUNING_ENABLED:
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=100, n_jobs=-1, timeout=4*60)
    
    print("Best hyperparameters:", study.best_params)
    print(f"Best R² score: {study.best_value:.4f}")
# Out:
# [I 2025-04-25 15:16:00,292] A new study created in memory with name: no-name-a953e617-f2c9-4e64-8227-06af2447e5cb
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:03,343] Trial 3 finished with value: 0.0785260800773274 and parameters: {'feature_selection__estimator__alpha': 0.035631404847039735, 'svr__C': 0.20954579960613268, 'svr__gamma': 0.0058454271899313435, 'svr__epsilon': 0.40199079253922326, 'svr__kernel': 'rbf'}. Best is trial 3 with value: 0.0785260800773274.
# [I 2025-04-25 15:16:03,537] Trial 2 finished with value: 0.05593982011670919 and parameters: {'feature_selection__estimator__alpha': 0.024105233190127126, 'svr__C': 84.79989622653105, 'svr__gamma': 0.0717232960296774, 'svr__epsilon': 0.3689830139692835, 'svr__kernel': 'rbf'}. Best is trial 3 with value: 0.0785260800773274.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:03,684] Trial 7 finished with value: -0.0949736745451514 and parameters: {'feature_selection__estimator__alpha': 0.010634220630825267, 'svr__C': 0.7344626898335694, 'svr__gamma': 4.131584069493588, 'svr__epsilon': 0.44757092047437863, 'svr__kernel': 'rbf'}. Best is trial 3 with value: 0.0785260800773274.
# [I 2025-04-25 15:16:03,687] Trial 4 finished with value: -0.019064046304675918 and parameters: {'feature_selection__estimator__alpha': 0.01157287056247348, 'svr__C': 0.06461650386819444, 'svr__gamma': 0.009280552154038564, 'svr__epsilon': 0.4690356782180134, 'svr__kernel': 'rbf'}. Best is trial 3 with value: 0.0785260800773274.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:04,028] Trial 0 finished with value: -0.10382346510517589 and parameters: {'feature_selection__estimator__alpha': 0.001389273287582887, 'svr__C': 0.16002532845974385, 'svr__gamma': 1.333447969907738, 'svr__epsilon': 0.045363313361242115, 'svr__kernel': 'rbf'}. Best is trial 3 with value: 0.0785260800773274.
# [I 2025-04-25 15:16:04,203] Trial 6 finished with value: -0.10117582875660358 and parameters: {'feature_selection__estimator__alpha': 0.008537000443334095, 'svr__C': 0.491870067445225, 'svr__gamma': 2.5086332730776766, 'svr__epsilon': 0.05801128721148777, 'svr__kernel': 'rbf'}. Best is trial 3 with value: 0.0785260800773274.
# [I 2025-04-25 15:16:04,340] Trial 5 finished with value: -0.09296838685769371 and parameters: {'feature_selection__estimator__alpha': 0.0018411660511796451, 'svr__C': 92.9771424624747, 'svr__gamma': 2.8161843073679362, 'svr__epsilon': 0.02590076613671439, 'svr__kernel': 'rbf'}. Best is trial 3 with value: 0.0785260800773274.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:05,451] Trial 9 finished with value: 0.22893878288341582 and parameters: {'feature_selection__estimator__alpha': 0.028124040013075752, 'svr__C': 2.3960392387097724, 'svr__gamma': 0.003449921233113572, 'svr__epsilon': 0.28261801089624317, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:05,498] Trial 10 finished with value: -0.09134510948824202 and parameters: {'feature_selection__estimator__alpha': 0.05214571019534676, 'svr__C': 85.5693323363901, 'svr__gamma': 2.2060077638627535, 'svr__epsilon': 0.41122485566180705, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:05,879] Trial 14 finished with value: -0.10270317634791803 and parameters: {'feature_selection__estimator__alpha': 0.04666079030609184, 'svr__C': 0.01352529554958919, 'svr__gamma': 0.3956208366188417, 'svr__epsilon': 0.36063921536567356, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:05,961] Trial 12 finished with value: -0.09172672041659978 and parameters: {'feature_selection__estimator__alpha': 0.005276736076821992, 'svr__C': 47.132026654553776, 'svr__gamma': 5.885697367026844, 'svr__epsilon': 0.39034884273675263, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:06,119] Trial 13 finished with value: -0.09024439285849377 and parameters: {'feature_selection__estimator__alpha': 0.0034352194744383595, 'svr__C': 42.022626585988625, 'svr__gamma': 0.2138942827460225, 'svr__epsilon': 0.2696103701279668, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:06,239] Trial 1 finished with value: 0.043064038014979926 and parameters: {'feature_selection__estimator__alpha': 0.00025206618144051713, 'svr__C': 44.73225517740837, 'svr__gamma': 0.04103059649888816, 'svr__epsilon': 0.43770470822282836, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:06,469] Trial 8 finished with value: -0.09206346483932856 and parameters: {'feature_selection__estimator__alpha': 0.0009498434786755793, 'svr__C': 2.3384766530943595, 'svr__gamma': 1.849319638662647, 'svr__epsilon': 0.18554139905284533, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:06,988] Trial 15 finished with value: 0.19778274912397337 and parameters: {'feature_selection__estimator__alpha': 0.08671121948192875, 'svr__C': 52.07900483821337, 'svr__gamma': 0.0011442417917091722, 'svr__epsilon': 0.1634363487892082, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:07,143] Trial 16 finished with value: 0.09078865617985384 and parameters: {'feature_selection__estimator__alpha': 0.011148495616621975, 'svr__C': 1.1148646367307782, 'svr__gamma': 0.05317816957588447, 'svr__epsilon': 0.12914907481123003, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:07,782] Trial 20 finished with value: 0.20551354936129101 and parameters: {'feature_selection__estimator__alpha': 0.09163498540960442, 'svr__C': 6.580799414144848, 'svr__gamma': 0.0013583655186578097, 'svr__epsilon': 0.2534388749653951, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:08,669] Trial 21 finished with value: 0.21341465467673135 and parameters: {'feature_selection__estimator__alpha': 0.08011200859640284, 'svr__C': 4.9004299877375495, 'svr__gamma': 0.0010625192675680188, 'svr__epsilon': 0.27185235222961834, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:09,153] Trial 22 finished with value: 0.2076412094190751 and parameters: {'feature_selection__estimator__alpha': 0.09681799647574123, 'svr__C': 6.2921034138097225, 'svr__gamma': 0.0010314882933635137, 'svr__epsilon': 0.18545722343865387, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:09,608] Trial 23 finished with value: 0.21395569723453844 and parameters: {'feature_selection__estimator__alpha': 0.0741936500809389, 'svr__C': 6.891052311562893, 'svr__gamma': 0.0011796795486566766, 'svr__epsilon': 0.27621118463476946, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:10,547] Trial 24 finished with value: 0.19693727178732665 and parameters: {'feature_selection__estimator__alpha': 0.09396951944511496, 'svr__C': 7.971654956242514, 'svr__gamma': 0.0012673200825334876, 'svr__epsilon': 0.28693575558025103, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:12,379] Trial 25 finished with value: 0.14665467852507164 and parameters: {'feature_selection__estimator__alpha': 0.02120880542549255, 'svr__C': 8.3360230605195, 'svr__gamma': 0.0041288001286976074, 'svr__epsilon': 0.3000390192932112, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:12,943] Trial 26 finished with value: 0.1650048021126426 and parameters: {'feature_selection__estimator__alpha': 0.022648995666332487, 'svr__C': 5.708636760116388, 'svr__gamma': 0.005544566496197435, 'svr__epsilon': 0.2906289551837017, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:14,578] Trial 27 finished with value: 0.12611274162255065 and parameters: {'feature_selection__estimator__alpha': 0.02372563849797379, 'svr__C': 14.463420173836838, 'svr__gamma': 0.004870044811408514, 'svr__epsilon': 0.31454723895583414, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:16,096] Trial 11 finished with value: 0.019353702836952598 and parameters: {'feature_selection__estimator__alpha': 0.00010713075073888672, 'svr__C': 12.648081463916517, 'svr__gamma': 0.052449068367101476, 'svr__epsilon': 0.10866442614241041, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:16,287] Trial 28 finished with value: 0.18687640240821218 and parameters: {'feature_selection__estimator__alpha': 0.02191044489627385, 'svr__C': 2.9428481884499216, 'svr__gamma': 0.004140409378458342, 'svr__epsilon': 0.3089369373535143, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:16,908] Trial 18 finished with value: 0.21697479500461753 and parameters: {'feature_selection__estimator__alpha': 0.00020470141320073074, 'svr__C': 5.891245123153195, 'svr__gamma': 0.0015013664837713369, 'svr__epsilon': 0.2505823479946423, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:18,172] Trial 17 finished with value: 0.21856587853986023 and parameters: {'feature_selection__estimator__alpha': 0.00017092412128009036, 'svr__C': 7.379557916230368, 'svr__gamma': 0.0014118300945492133, 'svr__epsilon': 0.21246525958052287, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:18,769] Trial 31 finished with value: 0.19372083318344863 and parameters: {'feature_selection__estimator__alpha': 0.04914291931261923, 'svr__C': 1.5883577185834705, 'svr__gamma': 0.025654788183705143, 'svr__epsilon': 0.23429368462127823, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:18,936] Trial 30 finished with value: 0.19361866478186235 and parameters: {'feature_selection__estimator__alpha': 0.04111411458407994, 'svr__C': 2.3833424445185134, 'svr__gamma': 0.018733880915212425, 'svr__epsilon': 0.2285269671254294, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:19,043] Trial 29 finished with value: 0.21490039719668147 and parameters: {'feature_selection__estimator__alpha': 0.04322500544373993, 'svr__C': 2.3138323655772535, 'svr__gamma': 0.01374469515826491, 'svr__epsilon': 0.33392263792143434, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:19,574] Trial 19 finished with value: 0.22418566369387932 and parameters: {'feature_selection__estimator__alpha': 0.0001173732575528987, 'svr__C': 5.456473029403256, 'svr__gamma': 0.0010225628557728713, 'svr__epsilon': 0.25256945492383776, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:19,860] Trial 32 finished with value: 0.19851704370359147 and parameters: {'feature_selection__estimator__alpha': 0.042354167563188216, 'svr__C': 2.8744551384407315, 'svr__gamma': 0.013758087685718135, 'svr__epsilon': 0.20919304041881726, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:20,023] Trial 33 finished with value: 0.20888348652823296 and parameters: {'feature_selection__estimator__alpha': 0.04429806959932283, 'svr__C': 2.0607035038502666, 'svr__gamma': 0.015906320806750727, 'svr__epsilon': 0.23300155916867585, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:23,485] Trial 35 finished with value: 0.18023485280373397 and parameters: {'feature_selection__estimator__alpha': 0.0005040290410086059, 'svr__C': 1.546742641902833, 'svr__gamma': 0.014496277446125895, 'svr__epsilon': 0.2265753953253003, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:23,828] Trial 34 finished with value: 0.1615219262168212 and parameters: {'feature_selection__estimator__alpha': 0.0002559169738030181, 'svr__C': 1.742842185749884, 'svr__gamma': 0.017122681622156577, 'svr__epsilon': 0.21351959726014563, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:23,961] Trial 36 finished with value: 0.11317744222607347 and parameters: {'feature_selection__estimator__alpha': 0.00042910710321098774, 'svr__C': 0.491291149476357, 'svr__gamma': 0.002384135001593127, 'svr__epsilon': 0.2044116218477423, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:24,010] Trial 38 finished with value: 0.12342204534596982 and parameters: {'feature_selection__estimator__alpha': 0.000461817103697798, 'svr__C': 18.418159807688244, 'svr__gamma': 0.002726604396356466, 'svr__epsilon': 0.337454569776286, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:24,167] Trial 37 finished with value: 0.12499402703457738 and parameters: {'feature_selection__estimator__alpha': 0.00043814277377091326, 'svr__C': 19.077318640553063, 'svr__gamma': 0.0022834475193969496, 'svr__epsilon': 0.3424858695272288, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:24,751] Trial 39 finished with value: 0.13176275584170458 and parameters: {'feature_selection__estimator__alpha': 0.00034201721203782275, 'svr__C': 15.561634859309915, 'svr__gamma': 0.0024453437765362255, 'svr__epsilon': 0.21755582772789678, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:24,987] Trial 40 finished with value: 0.14070324705676762 and parameters: {'feature_selection__estimator__alpha': 0.0002894731274279139, 'svr__C': 14.441032196436899, 'svr__gamma': 0.0023841257938904455, 'svr__epsilon': 0.15127018934176859, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:25,055] Trial 41 finished with value: 0.07457317006818238 and parameters: {'feature_selection__estimator__alpha': 0.00036020211720696175, 'svr__C': 25.392373421335208, 'svr__gamma': 0.003151510865707134, 'svr__epsilon': 0.1371263003433389, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:29,250] Trial 44 finished with value: 0.09279238138464956 and parameters: {'feature_selection__estimator__alpha': 0.00016774528748027227, 'svr__C': 24.497001729956786, 'svr__gamma': 0.002541619987963192, 'svr__epsilon': 0.1529565449105245, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:32,554] Trial 42 finished with value: 0.12839946177513475 and parameters: {'feature_selection__estimator__alpha': 0.00011338534778367012, 'svr__C': 18.166633622453116, 'svr__gamma': 0.002332085786018817, 'svr__epsilon': 0.3411936994924224, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:33,058] Trial 43 finished with value: 0.11600850522600033 and parameters: {'feature_selection__estimator__alpha': 0.00011153888463974887, 'svr__C': 21.963983287536646, 'svr__gamma': 0.0023744545010747718, 'svr__epsilon': 0.34473212476428605, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:33,815] Trial 46 finished with value: 0.0315547415548834 and parameters: {'feature_selection__estimator__alpha': 0.00010653490565194823, 'svr__C': 0.19771233511922628, 'svr__gamma': 0.0021499793910638434, 'svr__epsilon': 0.14262372136863122, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:34,452] Trial 45 finished with value: 0.10775674862560862 and parameters: {'feature_selection__estimator__alpha': 0.00010423896143674304, 'svr__C': 20.06848504078989, 'svr__gamma': 0.0022612247772783836, 'svr__epsilon': 0.142291563999857, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:34,479] Trial 49 finished with value: 0.22268519992805774 and parameters: {'feature_selection__estimator__alpha': 0.0001263135679578019, 'svr__C': 4.311607565214428, 'svr__gamma': 0.001709273216733092, 'svr__epsilon': 0.25030239830597706, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:34,749] Trial 48 finished with value: 0.1689230243142637 and parameters: {'feature_selection__estimator__alpha': 0.0001251597472351576, 'svr__C': 3.5283941001876293, 'svr__gamma': 0.00994087386885955, 'svr__epsilon': 0.2511853065567748, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:34,953] Trial 47 finished with value: 0.1788156653146749 and parameters: {'feature_selection__estimator__alpha': 0.00010801476806815943, 'svr__C': 4.198533263057408, 'svr__gamma': 0.008060312563122389, 'svr__epsilon': 0.14747524207655116, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:39,291] Trial 53 finished with value: 0.19875311117730102 and parameters: {'feature_selection__estimator__alpha': 0.0007992735521445082, 'svr__C': 3.4474459679513703, 'svr__gamma': 0.006562532160588379, 'svr__epsilon': 0.25523654011501107, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:44,497] Trial 52 finished with value: 0.1924804618375618 and parameters: {'feature_selection__estimator__alpha': 0.000180702162969641, 'svr__C': 3.4696037309470014, 'svr__gamma': 0.006467043204478432, 'svr__epsilon': 0.24640803822772783, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:44,773] Trial 51 finished with value: 0.17089213297841938 and parameters: {'feature_selection__estimator__alpha': 0.000160330860366058, 'svr__C': 3.7433214266232353, 'svr__gamma': 0.008876447562612922, 'svr__epsilon': 0.25252767200623827, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:45,280] Trial 57 finished with value: -0.09854171335459497 and parameters: {'feature_selection__estimator__alpha': 0.00021444309389136832, 'svr__C': 0.6418619575048234, 'svr__gamma': 0.8079745543760344, 'svr__epsilon': 0.18651738676877, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:45,306] Trial 50 finished with value: 0.17369150273823683 and parameters: {'feature_selection__estimator__alpha': 0.00010625665674808545, 'svr__C': 3.7675691410365935, 'svr__gamma': 0.008369456639164833, 'svr__epsilon': 0.24850611895627933, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:45,778] Trial 54 finished with value: -0.09011786702758463 and parameters: {'feature_selection__estimator__alpha': 0.00018002157946223616, 'svr__C': 3.9344036290010145, 'svr__gamma': 0.16741493725185452, 'svr__epsilon': 0.2499471670179294, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:45,889] Trial 55 finished with value: 0.17571763769552043 and parameters: {'feature_selection__estimator__alpha': 0.00018064932036202801, 'svr__C': 3.9646783679689954, 'svr__gamma': 0.007739717353520346, 'svr__epsilon': 0.2530276563229496, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:45,939] Trial 56 finished with value: 0.12500446789049827 and parameters: {'feature_selection__estimator__alpha': 0.00018692066169054055, 'svr__C': 0.33422390906608823, 'svr__gamma': 0.008273241938528051, 'svr__epsilon': 0.0940284811977187, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:48,579] Trial 62 finished with value: 0.1392612639639978 and parameters: {'feature_selection__estimator__alpha': 0.015642168983509022, 'svr__C': 1.1488765964603953, 'svr__gamma': 0.0015800065847220923, 'svr__epsilon': 0.4158357833236649, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:49,293] Trial 61 finished with value: -0.0735854141800559 and parameters: {'feature_selection__estimator__alpha': 0.001686629245787166, 'svr__C': 1.0850379664774483, 'svr__gamma': 0.11059252080681299, 'svr__epsilon': 0.3214592305930199, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:49,413] Trial 64 finished with value: 0.18389759898438718 and parameters: {'feature_selection__estimator__alpha': 0.0026567770220973508, 'svr__C': 10.002234429644332, 'svr__gamma': 0.0015623224251396504, 'svr__epsilon': 0.40319397087761955, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:49,657] Trial 58 finished with value: 0.10159093315998921 and parameters: {'feature_selection__estimator__alpha': 0.00019226355892727412, 'svr__C': 0.7933528656053389, 'svr__gamma': 0.0016671777058381693, 'svr__epsilon': 0.39250194389533494, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:49,753] Trial 63 finished with value: 0.18327380525158468 and parameters: {'feature_selection__estimator__alpha': 0.002201863702475691, 'svr__C': 10.233607138438495, 'svr__gamma': 0.0015256124085086988, 'svr__epsilon': 0.3712243270547043, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:50,073] Trial 65 finished with value: 0.17941926372269018 and parameters: {'feature_selection__estimator__alpha': 0.0025196726629721326, 'svr__C': 10.378980395709354, 'svr__gamma': 0.0016136928266467683, 'svr__epsilon': 0.3789887844861157, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:51,745] Trial 69 finished with value: 0.18845093071741997 and parameters: {'feature_selection__estimator__alpha': 0.07068927815621949, 'svr__C': 10.183438050618847, 'svr__gamma': 0.003743198740819741, 'svr__epsilon': 0.27809989003985774, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:51,909] Trial 67 finished with value: 0.17647251256673768 and parameters: {'feature_selection__estimator__alpha': 0.006896604716897931, 'svr__C': 10.015516967365503, 'svr__gamma': 0.001547448286533056, 'svr__epsilon': 0.3813910679509879, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:52,175] Trial 70 finished with value: 0.2260950236552584 and parameters: {'feature_selection__estimator__alpha': 0.06409358270447059, 'svr__C': 6.626176401571304, 'svr__gamma': 0.0010011362888938864, 'svr__epsilon': 0.2787250082716054, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:52,194] Trial 59 finished with value: -0.09116355046383645 and parameters: {'feature_selection__estimator__alpha': 0.00019324938784718521, 'svr__C': 0.5943421410186603, 'svr__gamma': 0.11577043331605624, 'svr__epsilon': 0.32122544058630115, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:52,309] Trial 60 finished with value: 0.10894643194615164 and parameters: {'feature_selection__estimator__alpha': 0.00020095555267891295, 'svr__C': 0.542393954769492, 'svr__gamma': 0.0015920476885181206, 'svr__epsilon': 0.18251049451031084, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:52,734] Trial 66 finished with value: 0.1795725849046876 and parameters: {'feature_selection__estimator__alpha': 0.0007425535139553862, 'svr__C': 8.995542852631951, 'svr__gamma': 0.0015076732376409312, 'svr__epsilon': 0.4911861449564491, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:52,767] Trial 71 finished with value: 0.1642916664790843 and parameters: {'feature_selection__estimator__alpha': 0.0064975663704062965, 'svr__C': 5.990256504848008, 'svr__gamma': 0.0036048689404838416, 'svr__epsilon': 0.2804925478897574, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:53,439] Trial 72 finished with value: 0.18458908973839658 and parameters: {'feature_selection__estimator__alpha': 0.03138940631884467, 'svr__C': 6.414147876784133, 'svr__gamma': 0.003652081177430636, 'svr__epsilon': 0.2716502053072913, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:53,463] Trial 68 finished with value: 0.2029183080557872 and parameters: {'feature_selection__estimator__alpha': 0.0007033392650581113, 'svr__C': 10.616724465144875, 'svr__gamma': 0.0014924338950277646, 'svr__epsilon': 0.278034680145593, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:53,885] Trial 73 finished with value: 0.22834776531129583 and parameters: {'feature_selection__estimator__alpha': 0.029792347301793465, 'svr__C': 6.171516065885772, 'svr__gamma': 0.0010668348070702355, 'svr__epsilon': 0.2947288586025793, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:53,901] Trial 74 finished with value: 0.22169507371831387 and parameters: {'feature_selection__estimator__alpha': 0.06550488860271368, 'svr__C': 5.400393500021639, 'svr__gamma': 0.0010941732249988587, 'svr__epsilon': 0.2980523422811535, 'svr__kernel': 'rbf'}. Best is trial 9 with value: 0.22893878288341582.
# [I 2025-04-25 15:16:54,278] Trial 76 finished with value: 0.22966753758827746 and parameters: {'feature_selection__estimator__alpha': 0.031755236266206896, 'svr__C': 5.310693210249426, 'svr__gamma': 0.0010223092968415885, 'svr__epsilon': 0.2855419385300622, 'svr__kernel': 'rbf'}. Best is trial 76 with value: 0.22966753758827746.
# [I 2025-04-25 15:16:54,575] Trial 75 finished with value: 0.06646270578275164 and parameters: {'feature_selection__estimator__alpha': 0.029166232736002714, 'svr__C': 5.508145312742285, 'svr__gamma': 0.03063558435273413, 'svr__epsilon': 0.2973994775835084, 'svr__kernel': 'rbf'}. Best is trial 76 with value: 0.22966753758827746.
# [I 2025-04-25 15:16:54,889] Trial 77 finished with value: 0.22437142538099292 and parameters: {'feature_selection__estimator__alpha': 0.03218052486040885, 'svr__C': 7.052374054184188, 'svr__gamma': 0.0011106751586552174, 'svr__epsilon': 0.29098456922462834, 'svr__kernel': 'rbf'}. Best is trial 76 with value: 0.22966753758827746.
# [I 2025-04-25 15:16:55,396] Trial 78 finished with value: 0.22602810861685016 and parameters: {'feature_selection__estimator__alpha': 0.029185759944814614, 'svr__C': 5.4977473565074355, 'svr__gamma': 0.0010696020558743284, 'svr__epsilon': 0.3005117431832792, 'svr__kernel': 'rbf'}. Best is trial 76 with value: 0.22966753758827746.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:56,650] Trial 80 finished with value: 0.2346981662706386 and parameters: {'feature_selection__estimator__alpha': 0.05559827739192416, 'svr__C': 5.156523360190699, 'svr__gamma': 0.001040789382845964, 'svr__epsilon': 0.2961457690389516, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:16:56,683] Trial 79 finished with value: 0.20723050552186226 and parameters: {'feature_selection__estimator__alpha': 0.0587762585877453, 'svr__C': 2.4510581422651083, 'svr__gamma': 0.0011439998755566787, 'svr__epsilon': 0.3032914849032641, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:16:57,011] Trial 81 finished with value: 0.21862523968690156 and parameters: {'feature_selection__estimator__alpha': 0.06578915085776402, 'svr__C': 5.16083798708191, 'svr__gamma': 0.001044551155277901, 'svr__epsilon': 0.2992898514541259, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:16:57,056] Trial 82 finished with value: 0.22463530763535608 and parameters: {'feature_selection__estimator__alpha': 0.02955999342403373, 'svr__C': 4.7777879330413455, 'svr__gamma': 0.0010248248175740555, 'svr__epsilon': 0.2989022478947324, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:57,233] Trial 84 finished with value: -0.0839814218651396 and parameters: {'feature_selection__estimator__alpha': 0.05639583561406254, 'svr__C': 0.04639757593119925, 'svr__gamma': 0.0011319678029149815, 'svr__epsilon': 0.30356941820069744, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:16:57,273] Trial 83 finished with value: 0.21523637755628142 and parameters: {'feature_selection__estimator__alpha': 0.06493670218368178, 'svr__C': 4.770515510443422, 'svr__gamma': 0.001016120440736734, 'svr__epsilon': 0.29880455497341757, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:57,392] Trial 85 finished with value: 0.18342596459360486 and parameters: {'feature_selection__estimator__alpha': 0.01725390574934635, 'svr__C': 2.777512856892321, 'svr__gamma': 0.0010420489616318205, 'svr__epsilon': 0.3060963040598424, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:57,548] Trial 86 finished with value: 0.11564624769321256 and parameters: {'feature_selection__estimator__alpha': 0.01654439800624541, 'svr__C': 34.055962807507406, 'svr__gamma': 0.001124203020594408, 'svr__epsilon': 0.31228786634362465, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:58,683] Trial 88 finished with value: -0.09429887299797984 and parameters: {'feature_selection__estimator__alpha': 0.015741509590004928, 'svr__C': 0.010226957885152004, 'svr__gamma': 0.0011195618555482007, 'svr__epsilon': 0.2638349953619797, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:16:58,839] Trial 87 finished with value: 0.21515229970071545 and parameters: {'feature_selection__estimator__alpha': 0.053740454942568266, 'svr__C': 2.8881276776598526, 'svr__gamma': 0.0010071009994078604, 'svr__epsilon': 0.3570619677472761, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:16:58,994] Trial 90 finished with value: -0.05903618688244079 and parameters: {'feature_selection__estimator__alpha': 0.016792536347164107, 'svr__C': 0.08160398810560877, 'svr__gamma': 0.001974048986871884, 'svr__epsilon': 0.3235331158602742, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:16:59,028] Trial 89 finished with value: -0.05811802658515665 and parameters: {'feature_selection__estimator__alpha': 0.01621365837487316, 'svr__C': 0.08322497051018113, 'svr__gamma': 0.001937989463673319, 'svr__epsilon': 0.31263771069252816, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# /Users/bassel27/personal_projects/hireverse/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:1087: RuntimeWarning: invalid value encountered in divide
#   * (last_sum / last_over_new_count - new_sum) ** 2
# [I 2025-04-25 15:16:59,921] Trial 91 finished with value: 0.18253423754403122 and parameters: {'feature_selection__estimator__alpha': 0.017246283499041254, 'svr__C': 7.253610671260244, 'svr__gamma': 0.001211292509822831, 'svr__epsilon': 0.3509588873515296, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:17:00,270] Trial 94 finished with value: 0.21986373821126448 and parameters: {'feature_selection__estimator__alpha': 0.037010579300804154, 'svr__C': 2.0220869765446365, 'svr__gamma': 0.0020859458678353167, 'svr__epsilon': 0.3593896738891099, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:17:00,272] Trial 92 finished with value: 0.0912343358915538 and parameters: {'feature_selection__estimator__alpha': 0.016778944105760352, 'svr__C': 32.497937631900115, 'svr__gamma': 0.001978453167198689, 'svr__epsilon': 0.327224014048382, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:17:00,811] Trial 93 finished with value: 0.22596062382055687 and parameters: {'feature_selection__estimator__alpha': 0.03548863615369404, 'svr__C': 1.9498429867471512, 'svr__gamma': 0.0030716589974487704, 'svr__epsilon': 0.325559260227745, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:17:02,862] Trial 95 finished with value: 0.18948833225447634 and parameters: {'feature_selection__estimator__alpha': 0.03558821807968441, 'svr__C': 7.208227798011595, 'svr__gamma': 0.002107806424421879, 'svr__epsilon': 0.3293287799866437, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:17:03,065] Trial 98 finished with value: -0.09174432725184206 and parameters: {'feature_selection__estimator__alpha': 0.03454324179992356, 'svr__C': 7.572565427900268, 'svr__gamma': 8.868834034400585, 'svr__epsilon': 0.2656757025255059, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:17:03,094] Trial 96 finished with value: 0.1998095255489401 and parameters: {'feature_selection__estimator__alpha': 0.03394241883234375, 'svr__C': 1.437265407907686, 'svr__gamma': 0.002071855565753767, 'svr__epsilon': 0.32447869995578194, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:17:03,189] Trial 97 finished with value: 0.18052481269482695 and parameters: {'feature_selection__estimator__alpha': 0.035927006344827137, 'svr__C': 7.162051380626558, 'svr__gamma': 0.0031267789056043794, 'svr__epsilon': 0.2871226795890213, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# [I 2025-04-25 15:17:03,246] Trial 99 finished with value: 0.20796499104756588 and parameters: {'feature_selection__estimator__alpha': 0.027844299634226966, 'svr__C': 1.884813246666486, 'svr__gamma': 0.0018788964206124478, 'svr__epsilon': 0.2882101787742789, 'svr__kernel': 'rbf'}. Best is trial 80 with value: 0.2346981662706386.
# Best hyperparameters: {'feature_selection__estimator__alpha': 0.05559827739192416, 'svr__C': 5.156523360190699, 'svr__gamma': 0.001040789382845964, 'svr__epsilon': 0.2961457690389516, 'svr__kernel': 'rbf'}
# Best R² score: 0.2347

# %% [markdown]
# ## Store Trained Model

# %%
from sklearn import clone

if HYPERPARAMETER_TUNING_ENABLED:
    unfitted_pipeline.set_params(**study.best_params)
else:
    unfitted_pipeline.set_params(**PIPELINE_PARAMS)
fitted_pipeline = clone(unfitted_pipeline)
fitted_pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('dropper', 'drop',
#                                                   ['average_inner_brow_height_max',
#                                                    'average_inner_brow_height_median',
#                                                    'average_inner_brow_height_min',
#                                                    'average_inner_brow_height_std',
#                                                    'average_outer_brow_height_max',
#                                                    'average_outer_brow_height_median',
#                                                    'average_outer_brow_height_min',
#                                                    'average_oute...
#                                                    'outer_lip_height_std',
#                                                    'smile_max', 'smile_median',
#                                                    'smile_min', 'smile_std',
#                                                    'pitch_max', 'pitch_median', ...])])),
#                 ('imputer', SimpleImputer()), ('scaler', StandardScaler()),
#                 ('feature_selection',
#                  SelectFromModel(estimator=Lasso(alpha=0.05559827739192416,
#                                                  max_iter=50000))),
#                 ('svr',
#                  SVR(C=5.156523360190699, epsilon=0.2961457690389516,
#                      gamma=0.001040789382845964))])

# %% [markdown]
# ## Feature Selection Results

# %%
preprocessor = fitted_pipeline.named_steps['preprocessor']
feature_names = preprocessor.get_feature_names_out()    # after preprocessing

feature_selector = fitted_pipeline.named_steps['feature_selection']
selected_mask = feature_selector.get_support()

selected_features = feature_names[selected_mask]
unselected_features = feature_names[~selected_mask]

print(f"Number of Selected features ({len(selected_features)}):")
print(f"Selected features: {selected_features}")
print(f"Unselected features: {unselected_features}")
# Out:
# Number of Selected features (12):
# Selected features: ['remainder__intensity_mean' 'remainder__f3_sd' 'remainder__f2_f1_mean'
#  'remainder__percent_unvoiced' 'remainder__percent_breaks'
#  'remainder__inner_lip_height_mean' 'remainder__lip_corner_distance_mean'
#  'remainder__smile_mean' 'remainder__roll_mean'
#  'remainder__Duration/Total Words' 'remainder__They'
#  'remainder__Cognitive']
# Unselected features: ['remainder__f0_mean' 'remainder__f0_min' 'remainder__f0_max'
#  'remainder__f0_range' 'remainder__f0_sd' 'remainder__intensity_min'
#  'remainder__intensity_max' 'remainder__intensity_range'
#  'remainder__intensity_sd' 'remainder__f1_mean' 'remainder__f1_sd'
#  'remainder__f2_mean' 'remainder__f2_sd' 'remainder__f3_mean'
#  'remainder__f3_f1_mean' 'remainder__f2_f1_sd' 'remainder__f3_f1_sd'
#  'remainder__jitter' 'remainder__shimmer' 'remainder__pause_duration_max'
#  'remainder__pause_duration_avg' 'remainder__duration'
#  'remainder__average_outer_brow_height_mean'
#  'remainder__average_inner_brow_height_mean' 'remainder__eye_open_mean'
#  'remainder__outer_lip_height_mean' 'remainder__pitch_mean'
#  'remainder__yaw_mean' 'remainder__Total Words' 'remainder__Unique Words'
#  'remainder__Filler Words' 'remainder__Audio Duration (s)'
#  'remainder__Duration/Unique Words' 'remainder__Duration/Filler Words'
#  'remainder__Individual' 'remainder__We' 'remainder__Non-Fluences'
#  'remainder__PosEmotion' 'remainder__NegEmotion' 'remainder__Relativity'
#  'remainder__Quantifiers']

# %% [markdown]
# # Monte Carlo Cross Validation

# %%
from sklearn.model_selection import cross_validate
from sklearn.metrics import r2_score

scoring = {
    "r2": make_scorer(r2_score),
    "pearson": make_scorer(pearson_corr)
}

results = cross_validate(
    unfitted_pipeline,
    X,
    y,
    cv=GroupShuffleSplit(n_splits=1000, test_size=0.2, random_state=42),
    groups=groups_column,
    scoring=scoring,
    n_jobs=-1,
)

r2_scores = results["test_r2"]
pearson_scores = results["test_pearson"]
# Report the average performance and variability
avg_r2_score = np.mean(r2_scores)
print(
    f"Mean R² Score: {avg_r2_score:.2f} (±{np.std(r2_scores):.2f})"
)
avg_perason_score = np.mean(pearson_scores)
print(
    f"Mean Pearson Correlation: {avg_perason_score:.2f} (±{np.std(pearson_scores):.2f})"
)

# Mean R² Score: 0.20 (±0.23)
# Mean Pearson Correlation: 0.53 (±0.16)
# Out:
# Mean R² Score: 0.18 (±0.21)
# Mean Pearson Correlation: 0.51 (±0.16)

# %% [markdown]
# # Save the Model

# %%
from joblib import dump, load

dump(fitted_pipeline, os.path.join(BASE_DIR,'model_artifacts',f'regression_{target_column}.joblib'))
# Out:
# ['/Users/bassel27/personal_projects/hireverse/src/../model_artifacts/regression_RecommendHiring.joblib']
